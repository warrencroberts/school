# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
n = 1000
k = 20
data = np.linspace(0, 2, n)

# %%
plt.plot(data)
plt.plot(np.exp(data))

# %%
plt.yscale("log") 
plt.plot(data)
plt.plot(np.exp(data))
