# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # norm.pdf(x) = exp(-x**2/2)/sqrt(2*pi)

# %%
x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
gaussian_pdf =  norm.pdf(x)
plt.plot(x, gaussian_pdf,  'r-', lw=5, alpha=0.6, label='norm pdf')

# %%
y, x = np.histogram(gaussian_pdf, 40)
the_hist[1]
# Out:
# array([0.02665214, 0.03595664, 0.04526114, 0.05456564, 0.06387014,
#        0.07317464, 0.08247914, 0.09178364, 0.10108814, 0.11039264,
#        0.11969714, 0.12900164, 0.13830615, 0.14761065, 0.15691515,
#        0.16621965, 0.17552415, 0.18482865, 0.19413315, 0.20343765,
#        0.21274215, 0.22204665, 0.23135115, 0.24065565, 0.24996015,
#        0.25926465, 0.26856915, 0.27787365, 0.28717815, 0.29648265,
#        0.30578715, 0.31509165, 0.32439615, 0.33370065, 0.34300515,
#        0.35230965, 0.36161415, 0.37091865, 0.38022315, 0.38952765,
#        0.39883215])

# %%
y,x = np.histogram(gaussian_pdf,bins=40)

# bin centers
xx = (x[1:]+x[:-1])/2

plt.plot(xx,y)
plt.show()
